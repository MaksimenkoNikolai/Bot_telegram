# %%
import telebot
import COVID19Py
from telebot import types

bot = telebot.TeleBot('1292325033:AAFfg8euF08nC07PZe0w20gy_Kl0ncsuZ6Q')
covid19 = COVID19Py.COVID19()

@bot.message_handler(commands=['start'])
def start_message(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    but1= types.KeyboardButton('Во всём мире')
    but2= types.KeyboardButton('Who am i')
    markup.add(but1,but2)

    first_mess=f"<b>Здравствуйте, {message.from_user.first_name}</b>\nУкажите страну"
    bot.send_message(message.chat.id, first_mess,parse_mode='html',reply_markup=markup)


@bot.message_handler(content_types=['text'])
def mess(message):
    final_message = ""
    get_message_bot = message.text.strip().lower()
    get_message_bot =get_message_bot.replace(' ','').replace('-','').replace('*','').replace('.','').replace(',','')
    deaths_1=0
    infect=0
    if message.text == f"hoholздесь":
        final_message =f"приветствуюсоздатель"
    elif message.text ==f"1109рассказатьтебепроmylootbot?":
        final_message =f"ПОЖАЛУЙСТА НЕ УДАЛЯЙТЕ МЕНЯ\nя буду работать лучше"
    elif message.text ==f"1109чтобудешьделатьпослепандемии?":
        final_message =f"я могу присылать мемы, не удаляйте меня"
    elif message.text ==f"1109какты?":
        final_message =f"все работает исправно,глупые кожаные мешки не умеют грамотно писать"
    elif message.text ==f"1109какдела?":
        final_message =f"все работает исправно,глупые кожанные мешки не умеют грамотно писать"
    elif message.text ==f"1109отчёт":
        final_message =f"все работает исправно,глупые кожанные мешки не умеют грамотно писать"


    elif get_message_bot == "afghanistan":
         location = covid19.getLocationByCountryCode("AF")


    elif get_message_bot == "albania":
         location = covid19.getLocationByCountryCode("AL")
    elif get_message_bot == "algeria":
         location = covid19.getLocationByCountryCode("DZ")
    elif get_message_bot == "andorra":
         location = covid19.getLocationByCountryCode("AD")
    elif get_message_bot == "angola":
         location = covid19.getLocationByCountryCode("AO")
    elif get_message_bot == "argentina":
         location = covid19.getLocationByCountryCode("AR")
    elif get_message_bot == "armenia":
         location = covid19.getLocationByCountryCode("AM")

    elif get_message_bot == "austria":
         location = covid19.getLocationByCountryCode("AT")
    elif get_message_bot == "azerbaijan":
         location = covid19.getLocationByCountryCode("AZ")

    elif get_message_bot == "bahrain":
         location = covid19.getLocationByCountryCode("BH")
    elif get_message_bot == "bangladesh":
         location = covid19.getLocationByCountryCode("BD")


    elif get_message_bot == "barbados":
         location = covid19.getLocationByCountryCode("BB")
    elif get_message_bot == "belarus":
         location = covid19.getLocationByCountryCode("BY")
    elif get_message_bot == "belgium":
         location = covid19.getLocationByCountryCode("BE")
    elif get_message_bot == "benin":
         location = covid19.getLocationByCountryCode("BJ")
    elif get_message_bot == "bhutan":
         location = covid19.getLocationByCountryCode("BT")
    elif get_message_bot == "bolivia":
         location = covid19.getLocationByCountryCode("BO")

    elif get_message_bot == "brazil":
         location = covid19.getLocationByCountryCode("BR")
    elif get_message_bot == "brunei":
         location = covid19.getLocationByCountryCode("BN")
    elif get_message_bot == "bulgaria":
         location = covid19.getLocationByCountryCode("BG")



    elif get_message_bot == "caboverde":
         location = covid19.getLocationByCountryCode("CV")
    elif get_message_bot == "cambodia":
         location = covid19.getLocationByCountryCode("KH")
    elif get_message_bot == "cameroon":
         location = covid19.getLocationByCountryCode("CM")
   

    elif get_message_bot == "chad":
         location = covid19.getLocationByCountryCode("TD")
    elif get_message_bot == "chile":
         location = covid19.getLocationByCountryCode("CL")
   
    elif get_message_bot == "colombia":
         location = covid19.getLocationByCountryCode("CO")

    
    elif get_message_bot == "costarica":
         location = covid19.getLocationByCountryCode("CR")
    elif get_message_bot == "cotedivoire":
         location = covid19.getLocationByCountryCode("CI")
    elif get_message_bot == "берегслоновойкости":
         location = covid19.getLocationByCountryCode("CI")
    elif get_message_bot == "croatia":
         location = covid19.getLocationByCountryCode("HR")
    elif get_message_bot == "diamondprincess":
         location = covid19.getLocationByCountryCode("XX")
    elif get_message_bot == "cuba":
         location = covid19.getLocationByCountryCode("CU")
    elif get_message_bot == "cyprus":
         location = covid19.getLocationByCountryCode("CY")


    elif get_message_bot == "czechia":
         location = covid19.getLocationByCountryCode("CZ")
   
    elif get_message_bot == "djibouti":
         location = covid19.getLocationByCountryCode("DJ")
    elif get_message_bot == "dominicanrepublic":
         location = covid19.getLocationByCountryCode("DO")
    elif get_message_bot == "ecuador":
         location = covid19.getLocationByCountryCode("EC")
    elif get_message_bot == "egypt":
         location = covid19.getLocationByCountryCode("EG")



    elif get_message_bot == "eritrea":
         location = covid19.getLocationByCountryCode("ER")
    elif get_message_bot == "estonia":
         location = covid19.getLocationByCountryCode("EE")
    elif get_message_bot == "eswatini":
         location = covid19.getLocationByCountryCode("SZ")
    elif get_message_bot == "ethiopia":
         location = covid19.getLocationByCountryCode("ET")
    elif get_message_bot == "fiji":
         location = covid19.getLocationByCountryCode("FJ")
    elif get_message_bot == "finland":
         location = covid19.getLocationByCountryCode("FI")
   
    elif get_message_bot == "gabon":
         location = covid19.getLocationByCountryCode("GA")
    elif get_message_bot == "gambia":
         location = covid19.getLocationByCountryCode("GM")
    elif get_message_bot == "georgia":
         location = covid19.getLocationByCountryCode("GE")
    elif get_message_bot == "germany":
         location = covid19.getLocationByCountryCode("DE")


    elif get_message_bot == "ghana":
         location = covid19.getLocationByCountryCode("GH")
    elif get_message_bot == "greece":
         location = covid19.getLocationByCountryCode("GR")
    elif get_message_bot == "guatemala":
         location = covid19.getLocationByCountryCode("GT")
    elif get_message_bot == "guinea":
         location = covid19.getLocationByCountryCode("GN")
    elif get_message_bot == "guyana":
         location = covid19.getLocationByCountryCode("GY")
    elif get_message_bot == "haiti":
         location = covid19.getLocationByCountryCode("HT")
    elif get_message_bot == "holysee":
         location = covid19.getLocationByCountryCode("VA")
    elif get_message_bot == "honduras":
         location = covid19.getLocationByCountryCode("HN")
    elif get_message_bot == "hungary":
         location = covid19.getLocationByCountryCode("HU")
    elif get_message_bot == "iceland":
         location = covid19.getLocationByCountryCode("IS")


    elif get_message_bot == "india":
         location = covid19.getLocationByCountryCode("IN")
    elif get_message_bot == "indonesia":
         location = covid19.getLocationByCountryCode("ID")
    elif get_message_bot == "iran":
         location = covid19.getLocationByCountryCode("IR")
    elif get_message_bot == "iraq":
         location = covid19.getLocationByCountryCode("IQ")
    elif get_message_bot == "ireland":
         location = covid19.getLocationByCountryCode("IE")
    elif get_message_bot == "israel":
         location = covid19.getLocationByCountryCode("IL")
    elif get_message_bot == "italy":
         location = covid19.getLocationByCountryCode("IT")
    elif get_message_bot == "jamaica":
         location = covid19.getLocationByCountryCode("JM")
    elif get_message_bot == "japan":
         location = covid19.getLocationByCountryCode("JP")
    elif get_message_bot == "jordan":
         location = covid19.getLocationByCountryCode("JO")


    elif get_message_bot == "kazakhstan":
         location = covid19.getLocationByCountryCode("KZ")
    elif get_message_bot == "kenya":
         location = covid19.getLocationByCountryCode("KE")

    elif get_message_bot == "kuwait":
         location = covid19.getLocationByCountryCode("KW")
    elif get_message_bot == "kyrgyzstan":
         location = covid19.getLocationByCountryCode("KG")
    elif get_message_bot == "latvia":
         location = covid19.getLocationByCountryCode("LV")
    elif get_message_bot == "lebanon":
         location = covid19.getLocationByCountryCode("LB")
    elif get_message_bot == "liberia":
         location = covid19.getLocationByCountryCode("LR")
    elif get_message_bot == "liechtenstein":
         location = covid19.getLocationByCountryCode("LI")
    elif get_message_bot == "lithuania":
         location = covid19.getLocationByCountryCode("LT")


    elif get_message_bot == "luxembourg":
         location = covid19.getLocationByCountryCode("LU")
    elif get_message_bot == "madagascar":
         location = covid19.getLocationByCountryCode("MG")
    elif get_message_bot == "malaysia":
         location = covid19.getLocationByCountryCode("MY")
    elif get_message_bot == "maldives":
         location = covid19.getLocationByCountryCode("MV")
    elif get_message_bot == "malta":
         location = covid19.getLocationByCountryCode("MT")
    elif get_message_bot == "mauritania":
         location = covid19.getLocationByCountryCode("MR")
    elif get_message_bot == "mauritius":
         location = covid19.getLocationByCountryCode("MU")
    elif get_message_bot == "mexico":
         location = covid19.getLocationByCountryCode("MX")
    elif get_message_bot == "moldova":
         location = covid19.getLocationByCountryCode("MD")
    elif get_message_bot == "monaco":
         location = covid19.getLocationByCountryCode("MC")


    elif get_message_bot == "mongolia":
         location = covid19.getLocationByCountryCode("MN")
    elif get_message_bot == "montenegro":
         location = covid19.getLocationByCountryCode("ME")
    elif get_message_bot == "morocco":
         location = covid19.getLocationByCountryCode("MA")
    elif get_message_bot == "namibia":
         location = covid19.getLocationByCountryCode("NA")
    elif get_message_bot == "nepal":
         location = covid19.getLocationByCountryCode("NP")

    elif get_message_bot == "newzealand":
         location = covid19.getLocationByCountryCode("NZ")


    elif get_message_bot == "nicaragua":
         location = covid19.getLocationByCountryCode("NI")
    elif get_message_bot == "niger":
         location = covid19.getLocationByCountryCode("NE")
    elif get_message_bot == "nigeria":
         location = covid19.getLocationByCountryCode("NG")

    elif get_message_bot == "norway":
         location = covid19.getLocationByCountryCode("NO")
    elif get_message_bot == "oman":
         location = covid19.getLocationByCountryCode("OM")
    elif get_message_bot == "pakistan":
         location = covid19.getLocationByCountryCode("PK")
    elif get_message_bot == "panama":
         location = covid19.getLocationByCountryCode("PA")

    elif get_message_bot == "paraguay":
         location = covid19.getLocationByCountryCode("PY")


    elif get_message_bot == "peru":
         location = covid19.getLocationByCountryCode("PE")
    elif get_message_bot == "philippines":
         location = covid19.getLocationByCountryCode("PH")
    elif get_message_bot == "poland":
         location = covid19.getLocationByCountryCode("PL")
    elif get_message_bot == "portugal":
         location = covid19.getLocationByCountryCode("PT")
    elif get_message_bot == "qatar":
         location = covid19.getLocationByCountryCode("QA")
    elif get_message_bot == "romania":
         location = covid19.getLocationByCountryCode("RO")
    elif get_message_bot == "russia":
         location = covid19.getLocationByCountryCode("RU")
    elif get_message_bot == "rwanda":
         location = covid19.getLocationByCountryCode("RW")
    elif get_message_bot == "saintlucia":
         location = covid19.getLocationByCountryCode("LC")



    elif get_message_bot == "sanmarino":
         location = covid19.getLocationByCountryCode("SM")
    elif get_message_bot == "saudiarabia":
         location = covid19.getLocationByCountryCode("SA")
    elif get_message_bot == "senegal":
         location = covid19.getLocationByCountryCode("SN")
    elif get_message_bot == "serbia":
         location = covid19.getLocationByCountryCode("RS")

    elif get_message_bot == "singapore":
         location = covid19.getLocationByCountryCode("SG")
    elif get_message_bot == "slovakia":
         location = covid19.getLocationByCountryCode("SK")
    elif get_message_bot == "slovenia":
         location = covid19.getLocationByCountryCode("SI")
    elif get_message_bot == "somalia":
         location = covid19.getLocationByCountryCode("SO")
    elif get_message_bot == "southafrica":
         location = covid19.getLocationByCountryCode("ZA")


    elif get_message_bot == "spain":
         location = covid19.getLocationByCountryCode("ES")
    elif get_message_bot == "srilanka":
         location = covid19.getLocationByCountryCode("LK")
    elif get_message_bot == "sudan":
         location = covid19.getLocationByCountryCode("SD")
    elif get_message_bot == "suriname":
         location = covid19.getLocationByCountryCode("SR")
    elif get_message_bot == "sweden":
         location = covid19.getLocationByCountryCode("SE")
    elif get_message_bot == "switzerland":
         location = covid19.getLocationByCountryCode("CH")
    elif get_message_bot == "taiwan":
         location = covid19.getLocationByCountryCode("TW")
    elif get_message_bot == "tanzania":
         location = covid19.getLocationByCountryCode("TZ")
    elif get_message_bot == "thailand":
         location = covid19.getLocationByCountryCode("TH")
    elif get_message_bot == "togo":
         location = covid19.getLocationByCountryCode("TG")



    elif get_message_bot == "tunisia":
         location = covid19.getLocationByCountryCode("TN")
    elif get_message_bot == "turkey":
         location = covid19.getLocationByCountryCode("TR")
    elif get_message_bot == "uganda":
         location = covid19.getLocationByCountryCode("UG")
    elif get_message_bot == "ukraine":
         location = covid19.getLocationByCountryCode("UA")

    
    elif get_message_bot == "uruguay":
         location = covid19.getLocationByCountryCode("UY")

    elif get_message_bot == "uzbekistan":
         location = covid19.getLocationByCountryCode("UZ")
    elif get_message_bot == "venezuela":
         location = covid19.getLocationByCountryCode("VE")
    elif get_message_bot == "vietnam":
         location = covid19.getLocationByCountryCode("VN")
    elif get_message_bot == "zambia":
         location = covid19.getLocationByCountryCode("ZM")
    elif get_message_bot == "zimbabwe":
         location = covid19.getLocationByCountryCode("ZW")



#дополнение

    elif get_message_bot == "dominica":
         location = covid19.getLocationByCountryCode("DM")
    elif get_message_bot == "grenada":
         location = covid19.getLocationByCountryCode("GD")
    elif get_message_bot == "mozambique":
         location = covid19.getLocationByCountryCode("MZ")
    elif get_message_bot == "syria":
         location = covid19.getLocationByCountryCode("SY")
    elif get_message_bot == "timorleste":
         location = covid19.getLocationByCountryCode("TL")
    elif get_message_bot == "belize":
         location = covid19.getLocationByCountryCode("BZ")
   
    elif get_message_bot == "laos":
         location = covid19.getLocationByCountryCode("LA")
    elif get_message_bot == "libya":
         location = covid19.getLocationByCountryCode("LY")



    elif get_message_bot == "guineabissau":
         location = covid19.getLocationByCountryCode("GW")
    elif get_message_bot == "mali":
         location = covid19.getLocationByCountryCode("ML")
    elif get_message_bot == "saintkittsandnevis":
         location = covid19.getLocationByCountryCode("KN")
  
    elif get_message_bot == "kosovo":
         location = covid19.getLocationByCountryCode("XK")
    elif get_message_bot == "burma":
         location = covid19.getLocationByCountryCode("MM")


    elif get_message_bot == "botswana":
         location = covid19.getLocationByCountryCode("BW")
    elif get_message_bot == "burundi":
         location = covid19.getLocationByCountryCode("BI")
    elif get_message_bot == "sierraleone":
         location = covid19.getLocationByCountryCode("SL")
  
    elif get_message_bot == "malawi":
         location = covid19.getLocationByCountryCode("MW")

   



    elif get_message_bot == "westernsahara":
         location = covid19.getLocationByCountryCode("EH")
    elif get_message_bot == "yemen":
         location = covid19.getLocationByCountryCode("YE")
    elif get_message_bot == "comoros":
         location = covid19.getLocationByCountryCode("KM")
    elif get_message_bot == "коморскиеострова":
         location = covid19.getLocationByCountryCode("KM")
    elif get_message_bot == "коморы":
         location = covid19.getLocationByCountryCode("KM")
    elif get_message_bot == "коморскиеова":
         location = covid19.getLocationByCountryCode("KM")
    elif get_message_bot == "майотта":
         location = covid19.getLocationByCountryCode("KM")
    elif get_message_bot == "tajikistan":
         location = covid19.getLocationByCountryCode("TJ")

         #на русском


    elif get_message_bot == "афганистан":
         location = covid19.getLocationByCountryCode("AF")


    elif get_message_bot == "албания":
         location = covid19.getLocationByCountryCode("AL")
    elif get_message_bot == "алжир":
         location = covid19.getLocationByCountryCode("DZ")
    elif get_message_bot == "андорра":
         location = covid19.getLocationByCountryCode("AD")
    elif get_message_bot == "ангола":
         location = covid19.getLocationByCountryCode("AO")
    elif get_message_bot == "аргентина":
         location = covid19.getLocationByCountryCode("AR")
    elif get_message_bot == "армения":
         location = covid19.getLocationByCountryCode("AM")

    elif get_message_bot == "австрия":
         location = covid19.getLocationByCountryCode("AT")
    elif get_message_bot == "азербайджан":
         location = covid19.getLocationByCountryCode("AZ")

    elif get_message_bot == "бахрейн":
         location = covid19.getLocationByCountryCode("BH")
    elif get_message_bot == "бангладеш":
         location = covid19.getLocationByCountryCode("BD")


    elif get_message_bot == "барбадос":
         location = covid19.getLocationByCountryCode("BB")
    elif get_message_bot == "беларусь":
         location = covid19.getLocationByCountryCode("BY")
    elif get_message_bot == "бельгия":
         location = covid19.getLocationByCountryCode("BE")
    elif get_message_bot == "бенин":
         location = covid19.getLocationByCountryCode("BJ")
    elif get_message_bot == "бутан":
         location = covid19.getLocationByCountryCode("BT")
    elif get_message_bot == "боливия":
         location = covid19.getLocationByCountryCode("BO")

    elif get_message_bot == "бразилия":
         location = covid19.getLocationByCountryCode("BR")
    elif get_message_bot == "бруней":
         location = covid19.getLocationByCountryCode("BN")
    elif get_message_bot == "болгария":
         location = covid19.getLocationByCountryCode("BG")



    elif get_message_bot == "кабоверде":
         location = covid19.getLocationByCountryCode("CV")
    elif get_message_bot == "камбоджа":
         location = covid19.getLocationByCountryCode("KH")
    elif get_message_bot == "камерун":
         location = covid19.getLocationByCountryCode("CM")
   

    elif get_message_bot == "чад":
         location = covid19.getLocationByCountryCode("TD")
    elif get_message_bot == "чили":
         location = covid19.getLocationByCountryCode("CL")
   
    elif get_message_bot == "колумбия":
         location = covid19.getLocationByCountryCode("CO")

    
    elif get_message_bot == "костарика":
         location = covid19.getLocationByCountryCode("CR")
    elif get_message_bot == "котдивуар":
         location = covid19.getLocationByCountryCode("CI")
    elif get_message_bot == "хорватия":
         location = covid19.getLocationByCountryCode("HR")
    elif get_message_bot == "алмазнаяпринцесса":
         location = covid19.getLocationByCountryCode("XX")
    elif get_message_bot == "куба":
         location = covid19.getLocationByCountryCode("CU")
    elif get_message_bot == "кипр":
         location = covid19.getLocationByCountryCode("CY")


    elif get_message_bot == "чехия":
         location = covid19.getLocationByCountryCode("CZ")
   
    elif get_message_bot == "джибути":
         location = covid19.getLocationByCountryCode("DJ")
    elif get_message_bot == "доминиканскаяреспублика":
         location = covid19.getLocationByCountryCode("DO")
    elif get_message_bot == "доминиканы":
         location = covid19.getLocationByCountryCode("DO")
    elif get_message_bot == "эквадор":
         location = covid19.getLocationByCountryCode("EC")
    elif get_message_bot == "египет":
         location = covid19.getLocationByCountryCode("EG")



    elif get_message_bot == "эритрея":
         location = covid19.getLocationByCountryCode("ER")
    elif get_message_bot == "эстония":
         location = covid19.getLocationByCountryCode("EE")
    elif get_message_bot == "эсватини":
         location = covid19.getLocationByCountryCode("SZ")
    elif get_message_bot == "эфиопия":
         location = covid19.getLocationByCountryCode("ET")
    elif get_message_bot == "фиджи":
         location = covid19.getLocationByCountryCode("FJ")
    elif get_message_bot == "финляндия":
         location = covid19.getLocationByCountryCode("FI")
   
    elif get_message_bot == "габон":
         location = covid19.getLocationByCountryCode("GA")
    elif get_message_bot == "гамбия":
         location = covid19.getLocationByCountryCode("GM")
    elif get_message_bot == "грузия":
         location = covid19.getLocationByCountryCode("GE")
    elif get_message_bot == "германия":
         location = covid19.getLocationByCountryCode("DE")


    elif get_message_bot == "гана":
         location = covid19.getLocationByCountryCode("GH")
    elif get_message_bot == "греция":
         location = covid19.getLocationByCountryCode("GR")
    elif get_message_bot == "гватемала":
         location = covid19.getLocationByCountryCode("GT")
    elif get_message_bot == "гвинея":
         location = covid19.getLocationByCountryCode("GN")
    elif get_message_bot == "гайана":
         location = covid19.getLocationByCountryCode("GY")
    elif get_message_bot == "гаити":
         location = covid19.getLocationByCountryCode("HT")
    elif get_message_bot == "святойпрестол":
         location = covid19.getLocationByCountryCode("VA")
    elif get_message_bot == "гондурас":
         location = covid19.getLocationByCountryCode("HN")
    elif get_message_bot == "венгрия":
         location = covid19.getLocationByCountryCode("HU")
    elif get_message_bot == "исландия":
         location = covid19.getLocationByCountryCode("IS")


    elif get_message_bot == "индия":
         location = covid19.getLocationByCountryCode("IN")
    elif get_message_bot == "индонезия":
         location = covid19.getLocationByCountryCode("ID")
    elif get_message_bot == "иран":
         location = covid19.getLocationByCountryCode("IR")
    elif get_message_bot == "ирак":
         location = covid19.getLocationByCountryCode("IQ")
    elif get_message_bot == "ирландия":
         location = covid19.getLocationByCountryCode("IE")
    elif get_message_bot == "израиль":
         location = covid19.getLocationByCountryCode("IL")
    elif get_message_bot == "италия":
         location = covid19.getLocationByCountryCode("IT")
    elif get_message_bot == "ямайка":
         location = covid19.getLocationByCountryCode("JM")
    elif get_message_bot == "япония":
         location = covid19.getLocationByCountryCode("JP")
    elif get_message_bot == "джордан":
         location = covid19.getLocationByCountryCode("JO")


    elif get_message_bot == "казахстан":
         location = covid19.getLocationByCountryCode("KZ")
    elif get_message_bot == "кения":
         location = covid19.getLocationByCountryCode("KE")

    elif get_message_bot == "кувейт":
         location = covid19.getLocationByCountryCode("KW")
    elif get_message_bot == "кыргызстан":
         location = covid19.getLocationByCountryCode("KG")
    elif get_message_bot == "латвия":
         location = covid19.getLocationByCountryCode("LV")
    elif get_message_bot == "ливан":
         location = covid19.getLocationByCountryCode("LB")
    elif get_message_bot == "либерия":
         location = covid19.getLocationByCountryCode("LR")
    elif get_message_bot == "лихтенштейн":
         location = covid19.getLocationByCountryCode("LI")
    elif get_message_bot == "литва":
         location = covid19.getLocationByCountryCode("LT")


    elif get_message_bot == "люксембург":
         location = covid19.getLocationByCountryCode("LU")
    elif get_message_bot == "мадагаскар":
         location = covid19.getLocationByCountryCode("MG")
    elif get_message_bot == "малайзия":
         location = covid19.getLocationByCountryCode("MY")
    elif get_message_bot == "мальдивы":
         location = covid19.getLocationByCountryCode("MV")
    elif get_message_bot == "мальта":
         location = covid19.getLocationByCountryCode("MT")
    elif get_message_bot == "мавритания":
         location = covid19.getLocationByCountryCode("MR")
    elif get_message_bot == "маврикий":
         location = covid19.getLocationByCountryCode("MU")
    elif get_message_bot == "мексика":
         location = covid19.getLocationByCountryCode("MX")
    elif get_message_bot == "молдова":
         location = covid19.getLocationByCountryCode("MD")
    elif get_message_bot == "монако":
         location = covid19.getLocationByCountryCode("MC")


    elif get_message_bot == "монголия":
         location = covid19.getLocationByCountryCode("MN")
    elif get_message_bot == "черногория":
         location = covid19.getLocationByCountryCode("ME")
    elif get_message_bot == "марокко":
         location = covid19.getLocationByCountryCode("MA")
    elif get_message_bot == "намибия":
         location = covid19.getLocationByCountryCode("NA")
    elif get_message_bot == "непал":
         location = covid19.getLocationByCountryCode("NP")

    elif get_message_bot == "новаязеландия":
         location = covid19.getLocationByCountryCode("NZ")


    elif get_message_bot == "никарагуа":
         location = covid19.getLocationByCountryCode("NI")
    elif get_message_bot == "нигер":
         location = covid19.getLocationByCountryCode("NE")
    elif get_message_bot == "нигерия":
         location = covid19.getLocationByCountryCode("NG")

    elif get_message_bot == "норвегия":
         location = covid19.getLocationByCountryCode("NO")
    elif get_message_bot == "оман":
         location = covid19.getLocationByCountryCode("OM")
    elif get_message_bot == "пакистан":
         location = covid19.getLocationByCountryCode("PK")
    elif get_message_bot == "панама":
         location = covid19.getLocationByCountryCode("PA")

    elif get_message_bot == "парагвай":
         location = covid19.getLocationByCountryCode("PY")


    elif get_message_bot == "перу":
         location = covid19.getLocationByCountryCode("PE")
    elif get_message_bot == "филиппины":
         location = covid19.getLocationByCountryCode("PH")
    elif get_message_bot == "польша":
         location = covid19.getLocationByCountryCode("PL")
    elif get_message_bot == "португалия":
         location = covid19.getLocationByCountryCode("PT")
    elif get_message_bot == "катар":
         location = covid19.getLocationByCountryCode("QA")
    elif get_message_bot == "румыния":
         location = covid19.getLocationByCountryCode("RO")
    elif get_message_bot == "россия":
         location = covid19.getLocationByCountryCode("RU")
    elif get_message_bot == "руанда":
         location = covid19.getLocationByCountryCode("RW")
    elif get_message_bot == "сентлюсия":
         location = covid19.getLocationByCountryCode("LC")



    elif get_message_bot == "санмарино":
         location = covid19.getLocationByCountryCode("SM")
    elif get_message_bot == "саудовскаяаравия":
         location = covid19.getLocationByCountryCode("SA")
    elif get_message_bot == "сенегал":
         location = covid19.getLocationByCountryCode("SN")
    elif get_message_bot == "сербия":
         location = covid19.getLocationByCountryCode("RS")

    elif get_message_bot == "сингапур":
         location = covid19.getLocationByCountryCode("SG")
    elif get_message_bot == "словакия":
         location = covid19.getLocationByCountryCode("SK")
    elif get_message_bot == "словения":
         location = covid19.getLocationByCountryCode("SI")
    elif get_message_bot == "сомали":
         location = covid19.getLocationByCountryCode("SO")
    elif get_message_bot == "южнаяафрика":
         location = covid19.getLocationByCountryCode("ZA")


    elif get_message_bot == "испания":
         location = covid19.getLocationByCountryCode("ES")
    elif get_message_bot == "шриланка":
         location = covid19.getLocationByCountryCode("LK")
    elif get_message_bot == "судан":
         location = covid19.getLocationByCountryCode("SD")
    elif get_message_bot == "суринам":
         location = covid19.getLocationByCountryCode("SR")
    elif get_message_bot == "швеция":
         location = covid19.getLocationByCountryCode("SE")
    elif get_message_bot == "швейцария":
         location = covid19.getLocationByCountryCode("CH")
    elif get_message_bot == "тайвань":
         location = covid19.getLocationByCountryCode("TW")
    elif get_message_bot == "танзания":
         location = covid19.getLocationByCountryCode("TZ")
    elif get_message_bot == "таиланд":
         location = covid19.getLocationByCountryCode("TH")
    elif get_message_bot == "Того":
         location = covid19.getLocationByCountryCode("TG")



    elif get_message_bot == "тунис":
         location = covid19.getLocationByCountryCode("TN")
    elif get_message_bot == "турция":
         location = covid19.getLocationByCountryCode("TR")
    elif get_message_bot == "уганда":
         location = covid19.getLocationByCountryCode("UG")
    elif get_message_bot == "украина":
         location = covid19.getLocationByCountryCode("UA")

    
    elif get_message_bot == "уругвай":
         location = covid19.getLocationByCountryCode("UY")

    elif get_message_bot == "узбекистан":
         location = covid19.getLocationByCountryCode("UZ")
    elif get_message_bot == "венесуэла":
         location = covid19.getLocationByCountryCode("VE")
    elif get_message_bot == "вьетнам":
         location = covid19.getLocationByCountryCode("VN")
    elif get_message_bot == "замбия":
         location = covid19.getLocationByCountryCode("ZM")
    elif get_message_bot == "зимбабве":
         location = covid19.getLocationByCountryCode("ZW")

#дополнение



    elif get_message_bot == "доминика":
         location = covid19.getLocationByCountryCode("DM")
    elif get_message_bot == "гренада":
         location = covid19.getLocationByCountryCode("GD")
    elif get_message_bot == "мозамбик":
         location = covid19.getLocationByCountryCode("MZ")
    elif get_message_bot == "сирия":
         location = covid19.getLocationByCountryCode("SY")
    elif get_message_bot == "тиморлешти":
         location = covid19.getLocationByCountryCode("TL")
    elif get_message_bot == "белиз":
         location = covid19.getLocationByCountryCode("BZ")
   
    elif get_message_bot == "лаос":
         location = covid19.getLocationByCountryCode("LA")
    elif get_message_bot == "ливия":
         location = covid19.getLocationByCountryCode("LY")



    elif get_message_bot == "гвинеябисау":
         location = covid19.getLocationByCountryCode("GW")
    elif get_message_bot == "мали":
         location = covid19.getLocationByCountryCode("ML")
    elif get_message_bot == "сенткитсиневис":
         location = covid19.getLocationByCountryCode("KN")
  
    elif get_message_bot == "косово":
         location = covid19.getLocationByCountryCode("XK")
    elif get_message_bot == "бирма":
         location = covid19.getLocationByCountryCode("MM")


    elif get_message_bot == "ботсвана":
         location = covid19.getLocationByCountryCode("BW")
    elif get_message_bot == "бурунди":
         location = covid19.getLocationByCountryCode("BI")
    elif get_message_bot == "сьерралеоне":
         location = covid19.getLocationByCountryCode("SL")
  
    elif get_message_bot == "малави":
         location = covid19.getLocationByCountryCode("MW")


#дополнение 2
    elif get_message_bot == "antiguaanbarbuda":
         location = covid19.getLocationByCountryCode("AG")
    elif get_message_bot == "антигуаибарбуда":
         location = covid19.getLocationByCountryCode("AG")
    elif get_message_bot == "bahamas":
         location = covid19.getLocationByCountryCode("BS")
    elif get_message_bot == "багамы":
         location = covid19.getLocationByCountryCode("BS")
    elif get_message_bot == "багамскиеострова":
         location = covid19.getLocationByCountryCode("BS")
    elif get_message_bot == "багамскиеова":
         location = covid19.getLocationByCountryCode("BS")
    elif get_message_bot == "bosniaandherzegovina":
         location = covid19.getLocationByCountryCode("BA")
    elif get_message_bot == "босняигерцеговина":
         location = covid19.getLocationByCountryCode("BA")
    elif get_message_bot == "burkinafaso":
         location = covid19.getLocationByCountryCode("BF")
    elif get_message_bot == "буркинафаско":
         location = covid19.getLocationByCountryCode("BF")
    elif get_message_bot == "centralafricanrepublic":
         location = covid19.getLocationByCountryCode("CF")
    elif get_message_bot == "africanrepublic":
         location = covid19.getLocationByCountryCode("CF")
    elif get_message_bot == "центральноафриканскаяреспублика":
         location = covid19.getLocationByCountryCode("CF")
    elif get_message_bot == "центральнаяафрика":
         location = covid19.getLocationByCountryCode("CF")
    elif get_message_bot == "congobrazzaville":
         location = covid19.getLocationByCountryCode("CG")
    elif get_message_bot == "конгобраззавиль":
         location = covid19.getLocationByCountryCode("CG")
    elif get_message_bot == "браззавиль":
         location = covid19.getLocationByCountryCode("CG")   
    elif get_message_bot == "congokinshasa":
         location = covid19.getLocationByCountryCode("CD")
    elif get_message_bot == "конгокиншаса":
         location = covid19.getLocationByCountryCode("CD")
    elif get_message_bot == "киншаса":
         location = covid19.getLocationByCountryCode("CD")   
    elif get_message_bot == "congo":
         deaths_1=0
         infect=1
         location = covid19.getLocationByCountryCode("CD") 
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("CG") 
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])
    elif get_message_bot == "equatorialguinea":
         location = covid19.getLocationByCountryCode("GQ")
    elif get_message_bot == "guinea":
         location = covid19.getLocationByCountryCode("GQ")
    elif get_message_bot == "экваториальнаягвинея":
         location = covid19.getLocationByCountryCode("GQ")  
    elif get_message_bot == "гвинея":
         location = covid19.getLocationByCountryCode("GQ") 

    elif get_message_bot == "elsalvador":
         location = covid19.getLocationByCountryCode("SV")
    elif get_message_bot == "salvador":
         location = covid19.getLocationByCountryCode("SV")
    elif get_message_bot == "сальвадор":
         location = covid19.getLocationByCountryCode("SV")  
    elif get_message_bot == "эльсальвадор":
         location = covid19.getLocationByCountryCode("SV") 

    elif get_message_bot == "southkorea":
         location = covid19.getLocationByCountryCode("KR")
    elif get_message_bot == "korea":
         location = covid19.getLocationByCountryCode("KR")
    elif get_message_bot == "корея":
         location = covid19.getLocationByCountryCode("KR")  
    elif get_message_bot == "южнаякорея":
         location = covid19.getLocationByCountryCode("KR") 

    elif get_message_bot == "northmacedonia":
         location = covid19.getLocationByCountryCode("MK")
    elif get_message_bot == "macedonia":
         location = covid19.getLocationByCountryCode("MK")
    elif get_message_bot == "севернаямакедония":
         location = covid19.getLocationByCountryCode("MK")  
    elif get_message_bot == "македония":
         location = covid19.getLocationByCountryCode("MK") 


    elif get_message_bot == "papuanewguinea":
         location = covid19.getLocationByCountryCode("PG")
    elif get_message_bot == "papua":
         location = covid19.getLocationByCountryCode("PG")
    elif get_message_bot == "newguinea":
         location = covid19.getLocationByCountryCode("PG")  
    elif get_message_bot == "папуановаягвиннея":
         location = covid19.getLocationByCountryCode("PG") 
    elif get_message_bot == "папуа":
         location = covid19.getLocationByCountryCode("PG")
    elif get_message_bot == "новаягвиннея":
         location = covid19.getLocationByCountryCode("PG")



    elif get_message_bot == "saintvincentandthegrenadines":
         location = covid19.getLocationByCountryCode("VC")
    elif get_message_bot == "saintvincent":
         location = covid19.getLocationByCountryCode("VC")
    elif get_message_bot == "thegrenadines":
         location = covid19.getLocationByCountryCode("VC")  
    elif get_message_bot == "святойвинсентигренадины":
         location = covid19.getLocationByCountryCode("VC") 
    elif get_message_bot == "святойвинсент":
         location = covid19.getLocationByCountryCode("VC")
    elif get_message_bot == "гренадины":
         location = covid19.getLocationByCountryCode("VC")

    elif get_message_bot == "seychelles":
         location = covid19.getLocationByCountryCode("SC")
    elif get_message_bot == "сейшельскиеострова":
         location = covid19.getLocationByCountryCode("SC")
    elif get_message_bot == "сейшельскиеова":
         location = covid19.getLocationByCountryCode("SC")  
    elif get_message_bot == "сейшелы":
         location = covid19.getLocationByCountryCode("SC") 


    elif get_message_bot == "trinidadandtobago":
         location = covid19.getLocationByCountryCode("TT")
    elif get_message_bot == "tobago":
         location = covid19.getLocationByCountryCode("TT")
    elif get_message_bot == "trinidad":
         location = covid19.getLocationByCountryCode("TT")  
    elif get_message_bot == "тринидадитобаго":
         location = covid19.getLocationByCountryCode("TT") 
    elif get_message_bot == "тринидад":
         location = covid19.getLocationByCountryCode("TT")
    elif get_message_bot == "тобаго":
         location = covid19.getLocationByCountryCode("TT")

    elif get_message_bot == "unitedarabemirates":
         location = covid19.getLocationByCountryCode("AE")
    elif get_message_bot == "arabemirates":
         location = covid19.getLocationByCountryCode("AE")
    elif get_message_bot == "emirates":
         location = covid19.getLocationByCountryCode("AE")  
    elif get_message_bot == "эмираты":
         location = covid19.getLocationByCountryCode("AE") 
    elif get_message_bot == "арабскиеэмираты":
         location = covid19.getLocationByCountryCode("AE")
    elif get_message_bot == "объединенныеарабскиеэмираты":
         location = covid19.getLocationByCountryCode("AE")


    elif get_message_bot == "unitedstates":
         location = covid19.getLocationByCountryCode("US")
    elif get_message_bot == "america":
         location = covid19.getLocationByCountryCode("US")
    elif get_message_bot == "us":
         location = covid19.getLocationByCountryCode("US")  
    elif get_message_bot == "сша":
         location = covid19.getLocationByCountryCode("US") 
    elif get_message_bot == "америка":
         location = covid19.getLocationByCountryCode("US")
    elif get_message_bot == "объединенныештатыамерики":
         location = covid19.getLocationByCountryCode("US")


# особенные ***** страны

    elif get_message_bot == "china":
         deaths_1=0
         infect=0  
         for i in range(49,81):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("CN")
    elif get_message_bot == "китай":
         deaths_1=0
         infect=0  
         for i in range(49,81):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("CN")
    elif get_message_bot == "австралия":
         deaths_1=0
         infect=0  
         for i in range(8,15):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("AU") 
    elif get_message_bot == "australia":
         deaths_1=0
         infect=0  
         for i in range(8,15):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("AU") 
    elif get_message_bot == "канада":
         deaths_1=0
         infect=0  
         for i in range(35,45):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(245))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed']) 
         location = covid19.getLocationById(int(246))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])   
         location = covid19.getLocationById(int(238))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])  
         location = covid19.getLocationById(int(231))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])            
         location = covid19.getLocationByCountryCode("CA") 
    elif get_message_bot == "canada":
         deaths_1=0
         infect=0  
         for i in range(35,45):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(245))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed']) 
         location = covid19.getLocationById(int(246))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])   
         location = covid19.getLocationById(int(238))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])  
         location = covid19.getLocationById(int(231))
         deaths_1=deaths_1+int(location['latest']['deaths'])
         infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationByCountryCode("CA") 
    elif get_message_bot == "дания":

         for i in range(92,94):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         deaths_1=deaths_1+511
         infect=infect+9541
         location = covid19.getLocationByCountryCode("DK")          
    elif get_message_bot == "denmark":

         for i in range(92,94):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])  
         deaths_1=deaths_1+511
         infect=infect+9541
         location = covid19.getLocationByCountryCode("DK") 
    elif get_message_bot == "англия":   

         for i in range(217,223):
             location = covid19.getLocationById(i)
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         for i in range(249,251):
             location = covid19.getLocationById(int(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(258))
         deaths_1=deaths_1+int(location['latest']['deaths'])+28500
         infect=infect+int(location['latest']['confirmed'])+185000 
         location = covid19.getLocationByCountryCode("UK")       
    elif get_message_bot == "uk":   

         for i in range(217,223):
             location = covid19.getLocationById(i)
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         for i in range(249,251):
             location = covid19.getLocationById(int(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(258))
         deaths_1=deaths_1+int(location['latest']['deaths'])+28500
         infect=infect+int(location['latest']['confirmed'])+185000
    elif get_message_bot == "unitedkingdom":   
 
         for i in range(217,223):
             location = covid19.getLocationById(i)
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         for i in range(249,251):
             location = covid19.getLocationById(int(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(258))
         deaths_1=deaths_1+int(location['latest']['deaths'])+28500
         infect=infect+int(location['latest']['confirmed'])+185000
         location = covid19.getLocationByCountryCode("UK") 
    elif get_message_bot == "england":   
 
         for i in range(217,223):
             location = covid19.getLocationById(i)
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         for i in range(249,251):
             location = covid19.getLocationById(int(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById(int(258))
         deaths_1=deaths_1+int(location['latest']['deaths'])+28500
         infect=infect+int(location['latest']['confirmed'])+185000
         location = covid19.getLocationByCountryCode("UK") 
    elif get_message_bot == "нидерланды":   

         for i in range(166,169):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById('256')
         deaths_1=deaths_1+int(location['latest']['deaths'])+5000
         infect=infect+int(location['latest']['confirmed'])+41000
         location = covid19.getLocationByCountryCode("NL")
    elif get_message_bot == "netherlands":   
 
         for i in range(166,169):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById('256')
         deaths_1=deaths_1+int(location['latest']['deaths'])+5000
         infect=infect+int(location['latest']['confirmed'])+41000
         location = covid19.getLocationByCountryCode("NL")
    elif get_message_bot == "france":   
 
         for i in range(107,116):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById('256')
         deaths_1=deaths_1+int(location['latest']['deaths'])+24500
         infect=infect+int(location['latest']['confirmed'])+131000         
         location = covid19.getLocationByCountryCode("FR")
    elif get_message_bot == "франция":   
 
         for i in range(107,116):
             location = covid19.getLocationById(str(i))
             deaths_1=deaths_1+int(location['latest']['deaths'])
             infect=infect+int(location['latest']['confirmed'])
         location = covid19.getLocationById('259')
         deaths_1=deaths_1+int(location['latest']['deaths'])+24500
         infect=infect+int(location['latest']['confirmed'])+131000             
         location = covid19.getLocationByCountryCode("FR")





# конец особых
    elif get_message_bot == "западнаясахара":
         location = covid19.getLocationByCountryCode("EH")
    elif get_message_bot == "йемен":
         location = covid19.getLocationByCountryCode("YE")
    elif get_message_bot == "таджикистан":
         location = covid19.getLocationByCountryCode("TJ")






    elif get_message_bot == "вовсёммире":
        location = covid19.getLatest()
        final_message = f"<b>Данные по всему миру:</b>\n<b>Заболевших: </b>{location['confirmed']:,}\n<b>Сметрей: </b>{location['deaths']:,}"
    elif get_message_bot == "whoami":
        final_message =f"Я бот, написанный с целью осведомления населения о распространении COVID-19, а кто вы?"
    else:
        final_message = "Мы здесь не для того, чтобы общаться, верно\nВведите название страны"
    if (final_message == "") and (infect > 0):
        date = location[0]['last_updated'].split("T")
        time = date[1].split(".")
        final_message = f"<b>Данные по стране:</b>\nНаселение: {location[0]['country_population']:,}\n" \
                f"Последнее обновление: {date[0]} {time[0]}\nПоследние данные:\n<b>" \
                f"Заболевших: </b>{infect:,}\n<b>Сметрей: </b>" \
                f"{deaths_1:,}"
             
    if final_message == "":
        date = location[0]['last_updated'].split("T")
        time = date[1].split(".")
        final_message = f"<b>Данные по стране:</b>\nНаселение: {location[0]['country_population']:,}\n" \
                f"Последнее обновление: {date[0]} {time[0]}\nПоследние данные:\n<b>" \
                f"Заболевших: </b>{location[0]['latest']['confirmed']:,}\n<b>Сметрей: </b>" \
                f"{location[0]['latest']['deaths']:,}"

    bot.send_message(message.chat.id, final_message, parse_mode='html')

bot.polling(none_stop=True)
